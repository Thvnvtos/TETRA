# %% [markdown]
# # I2M2 small dataset [C, B1] Results
#
# ## HER1 Regions
# ![title](images/regions_I2M2_small.png)
#
# ## Average I2M2
# ![title](images/average_regions_I2M2_small.png)

# %% [markdown]
# # Combined results boxplot

# %% [markdown]
# ## No interpolation:
#
# ![title](images/result_nointerp_I2M2_small.png)
# ![title](images/heatmap_nointerp_I2M2_small.png)

# %% [markdown]
# ## With interpolation:
#
# ![title](images/result_nointerp_I2M2_small.png)
# ![title](images/heatmap_nointerp_I2M2_small.png)

# %% [markdown]
# ## Mean Sanity Check:
#
# ![title](images/result_nointerp_I2M2_small.png)
# ![title](images/heatmap_nointerp_I2M2_small.png)
