# %% [markdown]
# # IPR small dataset [C, B1] Results
#
# ## IPR values:
# ### mean = 16.67, std = 10.80
#
# ## HER1 Regions
# ![title](images/regions_small.png)
#
# ## Average IPR
# ![title](images/average_regions_IPR_small.png)

# %% [markdown]
# # Combined results:
#
# ### No interpolation = 6.97 +- 0.54
# ### With interpolation = 6.24 +- 0.53
# ### Mean sanity check = 8.84 +- 0.48
#
# ![title](images/combined_IPR_small.png)

# %% [markdown]
# ## No interpolation:
#
# ![title](images/result_nointerp_IPR_small.png)
# ![title](images/heatmap_nointerp_IPR_small.png)

# %% [markdown]
# ## With interpolation:
#
# ![title](images/result_interp_IPR_small.png)
# ![title](images/heatmap_interp_IPR_small.png)

# %% [markdown]
# ## Mean Sanity Check:
#
# ![title](images/result_mean_IPR_small.png)
# ![title](images/heatmap_mean_IPR_small.png)
