# %% [markdown]
# # IBD small dataset [C, B1] Results
#
# ## IBD values:
# ### mean = 14.17, std = 2.57
#
# ## HER1 Regions
# ![title](images/regions_small.png)
#
# ## Average IBD
# ![title](images/average_regions_IBD_small.png)

# %% [markdown]
# # Combined results:
#
# ### No interpolation = 1.72 +- 0.23
# ### With interpolation = 1.71 +- 0.1
# ### Mean sanity check = 1.92 +- 0.08
#
# ![title](images/combined_IBD_small.png)

# %% [markdown]
# ## No interpolation:
#
# ![title](images/result_nointerp_IBD_small.png)
# ![title](images/heatmap_nointerp_IBD_small.png)

# %% [markdown]
# ## With interpolation:
#
# ![title](images/result_interp_IBD_small.png)
# ![title](images/heatmap_interp_IBD_small.png)

# %% [markdown]
# ## Mean Sanity Check:
#
# ![title](images/result_mean_IBD_small.png)
# ![title](images/heatmap_mean_IBD_small.png)
